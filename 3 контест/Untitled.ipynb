# %%
def readLangSet(file):
    return set((file.readline().strip() for _ in range(int(file.readline()))))

def apply():
    file = open('input.txt')
    
    N = int(file.readline())

    all_lang = readLangSet(file)
    known_lang = all_lang.copy()
    for _ in range(N - 1):
        langSet = readLangSet(file)
        all_lang.update(langSet)
        known_lang.intersection_update(langSet)

    """print(len(known_lang))
    for lang in known_lang:
        print(lang)
    print(len(all_lang))
    for lang in all_lang:
        print(lang)"""

# %%
apply()
# Out:
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# Wall time: 0 ns
# ...

# %%
# %timeit apply()
# Out:
# 30 ms ± 188 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit apply()
# Out:
# 32.3 ms ± 357 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit !a.exe
# Out:
# 57.5 ms ± 2.5 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit !a.exe
# Out:
# 84 ms ± 5.83 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit !a.exe
# Out:
# 97.1 ms ± 3.75 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
